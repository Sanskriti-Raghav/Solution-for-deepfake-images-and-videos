# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f8c32242-c809-47a2-b75d-e7c31b907e20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8c32242-c809-47a2-b75d-e7c31b907e20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('data_folder')
print(os.listdir('data_folder'))
# Out:
# ['KAG_energydata_complete.csv']

# %%
import pandas as pd
df = pd.read_csv('data_folder/KAG_energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
print(df.isnull().sum())
df.describe()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df['hour'] = df['date'].dt.hour
df['dayofweek'] = df['date'].dt.dayofweek

# %%
from sklearn.decomposition import PCA
X = df.drop(['date','Appliances'], axis=1)
pca = PCA(n_components=20)  # Tune as needed
X_pca = pca.fit_transform(X)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
y = df['Appliances']
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
preds = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('MSE:', mean_squared_error(y_test, preds))
print('R2:', r2_score(y_test, preds))
# Out:
# MSE: 8305.817861259535
# R2: 0.17000676988064423

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # Regression output
])
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2)
deep_preds = model.predict(X_test)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19943.2676 - val_loss: 10543.1357
# Epoch 2/20
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10257.8389 - val_loss: 9559.9941
# Epoch 3/20
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9453.7578 - val_loss: 9169.2090
# Epoch 4/20
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9943.9404 - val_loss: 8932.2568
# Epoch 5/20
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 8654.2246 - val_loss: 8762.8887
# Epoch 6/20
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9374.5596 - val_loss: 8648.4150
# Epoch 7/20
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate metrics
mse = mean_squared_error(y_test, deep_preds)
mae = mean_absolute_error(y_test, deep_preds)
r2 = r2_score(y_test, deep_preds)

print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'R2 Score: {r2}')
# Out:
# Mean Squared Error: 7857.2421875
# Mean Absolute Error: 49.97433853149414
# R2 Score: 0.21483248472213745

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(list(y_test.values)[:100], label='Actual')
plt.plot(list(deep_preds[:100]), label='Predicted')
plt.legend()
plt.xlabel('Sample Index')
plt.ylabel('Appliance Energy Use')
plt.title('Predicted vs Actual Appliance Usage')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()
plt.figure(figsize=(15,12))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=15)
X_pca = pca.fit_transform(X)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, max_depth=15, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)

# %%
import numpy as np
# Generate random indices
n_samples = int(X_train.shape[0] * 0.1)
random_indices = np.random.choice(X_train.shape[0], size=n_samples, replace=False)

# Select the subset of data and labels
X_train_small = X_train[random_indices]
y_train_small = y_train.iloc[random_indices]

# %%
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [10, 15],
    'min_samples_split': [2, 5]
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

grid_search = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                           param_grid=param_grid,
                           cv=2, scoring='neg_mean_squared_error')
grid_search.fit(X_train_small, y_train_small)
print(grid_search.best_params_)
# Out:
# {'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_dist = {
    'n_estimators': randint(50, 200),
    'max_depth': randint(10, 20),
    'min_samples_split': randint(2, 10)
}

rand_search = RandomizedSearchCV(estimator=RandomForestRegressor(random_state=42),
                                 param_distributions=param_dist,
                                 n_iter=10, cv=3, scoring='neg_mean_squared_error', random_state=42)
rand_search.fit(X_train, y_train)
print(rand_search.best_params_)
# Out:
# {'max_depth': 17, 'min_samples_split': 5, 'n_estimators': 87}

# %%
import joblib
from sklearn.ensemble import RandomForestRegressor

# Assuming rand_search is done and best params found
best_params = rand_search.best_params_

# Retrain model on full training data with best hyperparameters
final_model = RandomForestRegressor(**best_params, random_state=42)
final_model.fit(X_train, y_train)

# Save model to file for deployment
joblib.dump(final_model, 'final_energy_model.pkl')
# Out:
# ['final_energy_model.pkl']

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

final_preds = final_model.predict(X_test)

mse = mean_squared_error(y_test, final_preds)
mae = mean_absolute_error(y_test, final_preds)
r2 = r2_score(y_test, final_preds)

print(f'Final Model MSE: {mse}')
print(f'Final Model MAE: {mae}')
print(f'Final Model R2: {r2}')
# Out:
# Final Model MSE: 4928.446103301983
# Final Model MAE: 34.459366235543285
# Final Model R2: 0.5075046227743247

# %%
import matplotlib.pyplot as plt
import pandas as pd

feat_importances = pd.Series(final_model.feature_importances_, index=X.columns)
feat_importances = feat_importances.sort_values(ascending=False)

plt.figure(figsize=(10,6))
feat_importances.plot(kind='bar')
plt.title('Feature Importance for Appliance Energy Usage')
plt.show()

# %%
import numpy as np

def predict_energy_usage(input_data):
    """
    input_data: list or array of feature values in order of X.columns
    Returns: predicted appliance energy usage
    """
    input_array = np.array(input_data).reshape(1, -1)
    prediction = final_model.predict(input_array)
    return float(prediction[0])
